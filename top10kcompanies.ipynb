# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/dhruvbharara/Downloads/companies.csv')

# %%
df
df.columns
df.count
df.shape

# %%
df.apply(len)
# Out:
# Company_name            10000
# Description             10000
# Ratings                 10000
# Highly_rated_for        10000
# Critically_rated_for    10000
# Total_reviews           10000
# Avg_salary              10000
# Interviews_taken        10000
# Total_jobs_available    10000
# Total_benefits          10000
# dtype: int64

# %%
df['Company_name']
# Out:
# 0                                 TCS
# 1                           Accenture
# 2                           Cognizant
# 3                               Wipro
# 4                           Capgemini
#                     ...
# 9995          Techila Global Services
# 9996              RxLogix Corporation
# 9997    Avians Innovations Technology
# 9998                     ACPL Systems
# 9999                        Beroe Inc
# Name: Company_name, Length: 10000, dtype: object

# %%
df[['Avg_salary' , 'Company_name']]
# Out:
#      Avg_salary                   Company_name
# 0        856.9k                            TCS
# 1        584.6k                      Accenture
# 2        561.5k                      Cognizant
# 3        427.4k                          Wipro
# 4        414.4k                      Capgemini
# ...         ...                            ...
# 9995        454        Techila Global Services
# 9996        799            RxLogix Corporation
# 9997        489  Avians Innovations Technology
# 9998        520                   ACPL Systems
# 9999        585                      Beroe Inc
#
# [10000 rows x 2 columns]

# %%
def converted_salary(Avg_salary):
    if isinstance(Avg_salary, str):
        if 'k' in Avg_salary:
            return float(Avg_salary.replace('k', '')) * 1000
        else:
            return (Avg_salary)
    else:
        # Handle cases where Avg_salary is already a float
        return Avg_salary

# %%
df['Avg_salary'] = df['Avg_salary'].apply(lambda x : converted_salary(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df['Avg_salary'] = df['Avg_salary'].apply(lambda x : converted_salary(x))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[51], line 1, in <lambda>(x)
# ----> 1 df['Avg_salary'] = df['Avg_salary'].apply(lambda x : converted_salary(x))
#
# Cell In[48], line 6, in converted_salary(Avg_salary)
#       4         return float(Avg_salary.replace('k', '')) * 1000
#       5     else:
# ----> 6         return float(Avg_salary)
#       7 else:
#       8     # Handle cases where Avg_salary is already a float
#       9     return Avg_salary
#
# ValueError: could not convert string to float: '--'

# %%
df.head(10)
# Out:
#     Company_name                                        Description  Ratings  \
# 0            TCS  IT Services & Consulting | 1 Lakh+ Employees |...      3.8
# 1      Accenture  IT Services & Consulting | 1 Lakh+ Employees |...      4.0
# 2      Cognizant  IT Services & Consulting | 1 Lakh+ Employees |...      3.9
# 3          Wipro  IT Services & Consulting | 1 Lakh+ Employees |...      3.8
# 4      Capgemini  IT Services & Consulting | 1 Lakh+ Employees |...      3.9
# 5      HDFC Bank  Banking | 1 Lakh+ Employees | Public | 30 year...      4.0
# 6     ICICI Bank  Banking | 1 Lakh+ Employees | Public | 30 year...      4.0
# 7        Infosys  IT Services & Consulting | 1 Lakh+ Employees |...      3.8
# 8        HCLTech  IT Services & Consulting | 1 Lakh+ Employees |...      3.7
# 9  Tech Mahindra  IT Services & Consulting | 1 Lakh+ Employees |...      3.7
#
#                                     Highly_rated_for  \
# 0                    Job Security, Work Life Balance
# 1  Company Culture, Skill Development / Learning,...
# 2                       Skill Development / Learning
# 3                                       Job Security
# 4  Job Security, Work Life Balance, Skill Develop...
# 5         Job Security, Skill Development / Learning
# 6  Job Security, Skill Development / Learning, Co...
# 7  Job Security, Company Culture, Skill Developme...
# 8                                       Job Security
# 9          Promotions / Appraisal, Salary & Benefits
#
#                                 Critically_rated_for Total_reviews Avg_salary  \
# 0          Promotions / Appraisal, Salary & Benefits         73.1k  8569000.0
# 1                                                NaN         46.4k  5846000.0
# 2                             Promotions / Appraisal         41.7k  5615000.0
# 3          Promotions / Appraisal, Salary & Benefits         39.2k  4274000.0
# 4          Promotions / Appraisal, Salary & Benefits           34k  4144000.0
# 5                             Promotions / Appraisal         33.9k  1323000.0
# 6                                                NaN         33.5k  1436000.0
# 7          Salary & Benefits, Promotions / Appraisal         31.8k  4620000.0
# 8  Promotions / Appraisal, Salary & Benefits, Wor...         28.5k  2934000.0
# 9                                                NaN         27.6k  2513000.0
#
#   Interviews_taken Total_jobs_available Total_benefits
# 0             6.1k                  847          11.5k
# 1             4.3k                 9.9k           7.1k
# 2             3.6k                  460           5.8k
# 3             3.7k                  405             5k
# 4             2.8k                  719             4k
# 5             1.5k                  335           3.2k
# 6             1.9k                  215           3.7k
# 7             4.8k                 1.1k           5.1k
# 8             2.5k                  408           4.1k
# 9             2.4k                 1.1k           3.6k
